# %%
import os
import pandas as pd

# %%
data=pd.read_csv("Part3 - vehicle.csv")

# %%
data.columns
# Out:
# Index(['compactness', 'circularity', 'distance_circularity', 'radius_ratio',
#        'pr.axis_aspect_ratio', 'max.length_aspect_ratio', 'scatter_ratio',
#        'elongatedness', 'pr.axis_rectangularity', 'max.length_rectangularity',
#        'scaled_variance', 'scaled_variance.1', 'scaled_radius_of_gyration',
#        'scaled_radius_of_gyration.1', 'skewness_about', 'skewness_about.1',
#        'skewness_about.2', 'hollows_ratio', 'class'],
#       dtype='object')

# %%
df1=pd.DataFrame(data['class'])

# %%
data=data.iloc[:,0:18].astype('float64')
data['class']=df1

# %%
data.dtypes
# Out:
# compactness                    float64
# circularity                    float64
# distance_circularity           float64
# radius_ratio                   float64
# pr.axis_aspect_ratio           float64
# max.length_aspect_ratio        float64
# scatter_ratio                  float64
# elongatedness                  float64
# pr.axis_rectangularity         float64
# max.length_rectangularity      float64
# scaled_variance                float64
# scaled_variance.1              float64
# scaled_radius_of_gyration      float64
# scaled_radius_of_gyration.1    float64
# skewness_about                 float64
# skewness_about.1               float64
# skewness_about.2               float64
# hollows_ratio                  float64
# class                           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# compactness                    0
# circularity                    5
# distance_circularity           4
# radius_ratio                   6
# pr.axis_aspect_ratio           2
# max.length_aspect_ratio        0
# scatter_ratio                  1
# elongatedness                  1
# pr.axis_rectangularity         3
# max.length_rectangularity      0
# scaled_variance                3
# scaled_variance.1              2
# scaled_radius_of_gyration      2
# scaled_radius_of_gyration.1    4
# skewness_about                 6
# skewness_about.1               1
# skewness_about.2               1
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
for i in data.columns:
    print(i)
    print(data[i].unique())
# Out:
# compactness
# [ 95.  91. 104.  93.  85. 107.  97.  90.  86.  88.  89.  94.  96.  99.
#  101.  84.  87.  83. 102.  80. 100.  82. 106.  81. 119.  78.  92.  98.
#  103.  77.  73.  79. 110. 108. 109. 111. 105. 112. 116. 113. 117. 115.
#   76. 114.]
# circularity
# [48. 41. 50. 44. nan 43. 34. 36. 46. 42. 49. 55. 54. 56. 47. 37. 39. 53.
#  45. 38. 35. 40. 59. 52. 51. 58. 57. 33.]
# distance_circularity
# [ 83.  84. 106.  82.  70.  73.  66.  62.  98.  74.  85.  79. 103.  51.
#   77. 100.  75.  53.  64. 105.  80.  54.  63. 107.  nan  72.  86.  68.
#  104.  87.  76.  81.  71. 101.  96.  78. 108.  91.  89.  94.  92.  60.
#   57.  65.  50.  88. 109.  95.  90.  58.  69.  47.  40.  59. 110.  93.
#  102. 112.  61.  42.  49.  44.  52.  55.]
# radius_ratio
# [178. 141. 209. 159. 205. 172. 173. 157. 140.  nan 143. 136. 171. 144.
#  203. 201. 109. 197. 186. 215. 153. 121. 148. 219. 154. 119. 193. 129.
#  160. 151. 222. 177. 118. 306. 176. 169. 214. 105. 137. 183. 220. 145.
# ...

# %%
import numpy as np
for i in data.columns:
    if (data[i].isnull().sum()>0):
        data[i].loc[data[i].isnull()==True]=data[i].mean()
# Out:
# C:\Users\hp pc\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\hp pc\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\hp pc\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data.isnull().sum()
# Out:
# compactness                    0
# circularity                    0
# distance_circularity           0
# radius_ratio                   0
# pr.axis_aspect_ratio           0
# max.length_aspect_ratio        0
# scatter_ratio                  0
# elongatedness                  0
# pr.axis_rectangularity         0
# max.length_rectangularity      0
# scaled_variance                0
# scaled_variance.1              0
# scaled_radius_of_gyration      0
# scaled_radius_of_gyration.1    0
# skewness_about                 0
# skewness_about.1               0
# skewness_about.2               0
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
contcol=data.columns
contcol[0:-1]
# Out:
# Index(['compactness', 'circularity', 'distance_circularity', 'radius_ratio',
#        'pr.axis_aspect_ratio', 'max.length_aspect_ratio', 'scatter_ratio',
#        'elongatedness', 'pr.axis_rectangularity', 'max.length_rectangularity',
#        'scaled_variance', 'scaled_variance.1', 'scaled_radius_of_gyration',
#        'scaled_radius_of_gyration.1', 'skewness_about', 'skewness_about.1',
#        'skewness_about.2', 'hollows_ratio'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(15,10))
for i,col in enumerate(contcol[0:-1]):
    ax=fig.add_subplot(3,6,i+1)
    sns.histplot(data[col])

# %%
data.corr()
# Out:
#                              compactness  circularity  distance_circularity  \
# compactness                     1.000000     0.685421              0.789909
# circularity                     0.685421     1.000000              0.793016
# distance_circularity            0.789909     0.793016              1.000000
# radius_ratio                    0.689840     0.620967              0.767079
# pr.axis_aspect_ratio            0.091704     0.153362              0.158397
# max.length_aspect_ratio         0.148249     0.251208              0.264550
# scatter_ratio                   0.812235     0.848207              0.904400
# elongatedness                  -0.788643    -0.821901             -0.911435
# pr.axis_rectangularity          0.813636     0.844972              0.893128
# max.length_rectangularity       0.676143     0.961943              0.774669
# scaled_variance                 0.762770     0.796822              0.861980
# ...

# %%
data.columns
# Out:
# Index(['compactness', 'circularity', 'distance_circularity', 'radius_ratio',
#        'pr.axis_aspect_ratio', 'max.length_aspect_ratio', 'scatter_ratio',
#        'elongatedness', 'pr.axis_rectangularity', 'max.length_rectangularity',
#        'scaled_variance', 'scaled_variance.1', 'scaled_radius_of_gyration',
#        'scaled_radius_of_gyration.1', 'skewness_about', 'skewness_about.1',
#        'skewness_about.2', 'hollows_ratio', 'class'],
#       dtype='object')

# %%
data.dtypes
# Out:
# compactness                    float64
# circularity                    float64
# distance_circularity           float64
# radius_ratio                   float64
# pr.axis_aspect_ratio           float64
# max.length_aspect_ratio        float64
# scatter_ratio                  float64
# elongatedness                  float64
# pr.axis_rectangularity         float64
# max.length_rectangularity      float64
# scaled_variance                float64
# scaled_variance.1              float64
# scaled_radius_of_gyration      float64
# scaled_radius_of_gyration.1    float64
# skewness_about                 float64
# skewness_about.1               float64
# skewness_about.2               float64
# hollows_ratio                  float64
# class                           object
# dtype: object

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=data,x='circularity',y='radius_ratio',hue='class',kind="strip")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='compactness',y='scatter_ratio',hue='class',height=5, aspect=2)
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='compactness',y='radius_ratio',hue='class',height=5, aspect=2)
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='circularity',y='compactness',hue='class',height=5, aspect=2,orient="v")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Buses have lowest values of compactness from circularity values of 42-47.
# No vans above circularity 50 exist.

# %%
sns.catplot(data=data,x='elongatedness',y='compactness',hue='class',height=5, aspect=2,orient="v")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Interesting distribution here.
# Cars seem to occupy higher density with higher compactness and lower elongatedness; and lower number towards the opposite.
# Buses concentrated in the middle and lesser density towards higher compactness and lower elongatedness. With little or no busses after the elongatedness of 46.
# Vans start to appear in the middle values of elongatedness (42) and compactness around 85.No vans appear below values of 80.

# %%
sns.catplot(data=data,x='distance_circularity',y='scaled_variance',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='circularity',y='scaled_radius_of_gyration',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='distance_circularity',y='scaled_radius_of_gyration.1',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='circularity',y='scaled_variance.1',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='skewness_about.2',y='scaled_radius_of_gyration',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(data=data,x='skewness_about.2',y='hollows_ratio',hue='class',height=5, aspect=3,orient="v")
plt.xticks(rotation=90)
plt.show()

# %%
from scipy.stats import zscore
dScaled=data.iloc[:,0:-1].apply(zscore)
dScaled.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0     0.160580     0.517302              0.056545      0.272965
# 1    -0.325470    -0.624564              0.120112     -0.835442
# 2     1.254193     0.843549              1.518571      1.201630
# 3    -0.082445    -0.624564             -0.007021     -0.296217
# 4    -1.054545    -0.135193             -0.769817      1.081803
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0              1.310206                 0.311542      -0.208038
# 1             -0.593962                 0.094079      -0.599893
# 2              0.548539                 0.311542       1.148382
# 3              0.167705                 0.094079      -0.750606
# 4              5.245485                 9.444962      -0.599893
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0       0.136580               -0.225160                   0.758332
# ...

# %%
covMatrix = np.cov(dScaled,rowvar=False)
print(covMatrix)
# Out:
# [[ 1.00118343  0.68623251  0.79084412  0.69065619  0.09181254  0.14842463
#    0.81319623 -0.78957587  0.81459888  0.67694334  0.76367265  0.81686705
#    0.58584865 -0.25036693  0.23596607  0.15757316  0.2988797   0.36598446]
#  [ 0.68623251  1.00118343  0.79395399  0.62170187  0.15354334  0.25150523
#    0.84921058 -0.82287347  0.84597164  0.96308094  0.7977645   0.83951746
#    0.92798524  0.05270433  0.14456452 -0.01186527 -0.1057698   0.04537164]
#  [ 0.79084412  0.79395399  1.00118343  0.76798667  0.15858456  0.26486339
#    0.90547061 -0.91251368  0.89418513  0.77558624  0.86300031  0.88837793
#    0.70678835 -0.2261194   0.1139479   0.26586756  0.14573497  0.3324884 ]
#  [ 0.69065619  0.62170187  0.76798667  1.00118343  0.6643445   0.45056889
#    0.73509724 -0.79072934  0.70912305  0.56987817  0.79498064  0.72100219
#    0.5371705  -0.1810333   0.04877731  0.17403799  0.38258162  0.47181974]
#  [ 0.09181254  0.15354334  0.15858456  0.6643445   1.00118343  0.64947191
# ...

# %%
dScaled.shape
# Out:
# (846, 18)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
pca.fit(dScaled)
# Out:
# PCA(n_components=18)

# %%
print(pca.explained_variance_)
# Out:
# [9.40828822e+00 3.01605477e+00 1.90347881e+00 1.18027268e+00
#  9.17174067e-01 5.39279825e-01 3.58566463e-01 2.21661730e-01
#  1.60036194e-01 9.17140864e-02 6.65751851e-02 4.59556829e-02
#  3.54023825e-02 2.67096104e-02 2.03690624e-02 1.74414127e-02
#  9.23357029e-03 3.08801865e-03]

# %%
print(pca.components_)
# Out:
# [[ 2.75259459e-01  2.93392341e-01  3.04556452e-01  2.67593206e-01
#    8.04938998e-02  9.72198560e-02  3.16872006e-01 -3.14042361e-01
#    3.13953009e-01  2.82790417e-01  3.09310530e-01  3.14149034e-01
#    2.72002525e-01 -2.09179819e-02  4.13316728e-02  5.83331566e-02
#    3.01560495e-02  7.40813666e-02]
#  [-1.27010856e-01  1.26217125e-01 -7.26862818e-02 -1.89635192e-01
#   -1.22158741e-01  1.07277825e-02  4.80473095e-02  1.27991503e-02
#    6.00351423e-02  1.16182501e-01  6.17536908e-02  5.32757796e-02
#    2.09279660e-01  4.88541866e-01 -5.49212020e-02 -1.24152855e-01
#   -5.40947666e-01 -5.40279812e-01]
#  [-1.19874162e-01 -2.51835016e-02 -5.60058748e-02  2.75066087e-01
#    6.42046458e-01  5.91799912e-01 -9.76530949e-02  5.74645766e-02
#   -1.09509169e-01 -1.69994013e-02  5.64656174e-02 -1.08711428e-01
#   -3.13685232e-02  2.86211092e-01 -1.15693651e-01 -7.54878378e-02
#    8.68929277e-03  3.95143108e-02]
#  [ 7.83109159e-02  1.87525528e-01 -7.07959698e-02 -4.22567515e-02
# ...

# %%
print(pca.explained_variance_ratio_)
# Out:
# [5.22064851e-01 1.67360538e-01 1.05623824e-01 6.54931979e-02
#  5.08938854e-02 2.99245766e-02 1.98968125e-02 1.22999843e-02
#  8.88039031e-03 5.08920430e-03 3.69424950e-03 2.55007565e-03
#  1.96447421e-03 1.48211326e-03 1.13027697e-03 9.67822019e-04
#  5.12369772e-04 1.71353806e-04]

# %%
plt.bar(list(range(1,19)),pca.explained_variance_ratio_,alpha=0.5, align='center')
plt.ylabel('Variation explained')
plt.xlabel('eigen Value')
plt.show()

# %%
plt.step(list(range(1,19)),np.cumsum(pca.explained_variance_ratio_), where='mid')
plt.ylabel('Cum of variation explained')
plt.xlabel('eigen Value')
plt.show()

# %% [markdown]
# Now 8 dimensions seems very reasonable. With 3 variables we can explain over 95% of the variation in the original data!

# %%
pca3 = PCA(n_components=8)
pca3.fit(dScaled)
print(pca3.components_)
print(pca3.explained_variance_ratio_)
Xpca3 = pca3.transform(dScaled)
# Out:
# [[ 2.75259459e-01  2.93392341e-01  3.04556452e-01  2.67593206e-01
#    8.04938998e-02  9.72198560e-02  3.16872006e-01 -3.14042361e-01
#    3.13953009e-01  2.82790417e-01  3.09310530e-01  3.14149034e-01
#    2.72002525e-01 -2.09179819e-02  4.13316728e-02  5.83331566e-02
#    3.01560495e-02  7.40813666e-02]
#  [-1.27010856e-01  1.26217125e-01 -7.26862818e-02 -1.89635192e-01
#   -1.22158741e-01  1.07277825e-02  4.80473095e-02  1.27991503e-02
#    6.00351423e-02  1.16182501e-01  6.17536908e-02  5.32757796e-02
#    2.09279660e-01  4.88541866e-01 -5.49212020e-02 -1.24152855e-01
#   -5.40947666e-01 -5.40279812e-01]
#  [-1.19874162e-01 -2.51835016e-02 -5.60058748e-02  2.75066087e-01
#    6.42046458e-01  5.91799912e-01 -9.76530949e-02  5.74645766e-02
#   -1.09509169e-01 -1.69994013e-02  5.64656174e-02 -1.08711428e-01
#   -3.13685232e-02  2.86211092e-01 -1.15693651e-01 -7.54878378e-02
#    8.68929277e-03  3.95143108e-02]
#  [ 7.83109159e-02  1.87525528e-01 -7.07959698e-02 -4.22567515e-02
# ...

# %%
Xpca3
# Out:
# array([[ 3.32393198e-01, -2.18638382e-01,  1.00128619e+00, ...,
#         -7.54813577e-01, -9.02186656e-01, -3.83358279e-01],
#        [-1.59374091e+00, -4.20549398e-01, -3.69264301e-01, ...,
#         -5.19073098e-01,  3.76234233e-01,  2.47624062e-01],
#        [ 3.76753509e+00,  1.95040767e-01,  8.82372311e-02, ...,
#          7.05376870e-01, -3.26422538e-02,  4.83438500e-01],
#        ...,
#        [ 4.80780979e+00, -1.82373823e-03,  5.32772800e-01, ...,
#         -2.19629919e-01,  5.72947835e-01,  1.10917677e-01],
#        [-3.29572788e+00, -1.00880341e+00, -3.57467658e-01, ...,
#         -4.03456798e-01, -2.05108892e-01,  3.19508398e-01],
#        [-4.76673461e+00,  3.34686477e-01, -5.68739264e-01, ...,
#         -3.36467836e-01,  5.72769602e-02, -2.48355712e-01]])

# %%
sns.pairplot(pd.DataFrame(Xpca3))

# %%
y=data['class']
X=Xpca3
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(dScaled,y,test_size=0.30,random_state=1)

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.025, C=3)   
clf.fit(X_train , y_train)
y_pred_sv = clf.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

def clf_scores(clf,y_predicted):
    #Accuracy
    acc_train = clf.score(X_train, y_train)*100
    acc_test = clf.score(X_test, y_test)*100
    
    roc = roc_auc_score(y_test, y_predicted)*100
    tn, fp, fn, tp = confusion_matrix(y_test, y_predicted).ravel()
    cm = confusion_matrix(y_test, y_predicted)
    correct = tp + tn
    incorrect = fp + fn
        
    return acc_train, acc_test, roc, correct, incorrect, cm

def clf_table(clf,y_predicted):
    cr=classification_report(y_test,y_predicted, digits=2)
    return cr
from sklearn import preprocessing
from sklearn.metrics import average_precision_score, confusion_matrix, accuracy_score, classification_report,f1_score
cr4=clf_table(y_test,y_pred_sv)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#          bus       0.92      0.97      0.94        59
#          car       0.98      0.97      0.97       133
#          van       0.95      0.92      0.93        62
#
#     accuracy                           0.96       254
#    macro avg       0.95      0.95      0.95       254
# weighted avg       0.96      0.96      0.96       254

# %% [markdown]
# With only about less than half of dimensions; we get an accuracy of 96%.
